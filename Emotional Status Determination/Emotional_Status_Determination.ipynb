# %%
# import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('ESD.csv')

# %%
df
# Out:
#      gsr_max  gsr_min  min_ra  max_ra  gsr_mean  gsr_sd  gsr_var   ecg_avg  \
# 0       9.65     7.50   0.777   1.287     8.396   0.569    0.323  0.930028
# 1      10.04     6.91   0.688   1.453     7.763   0.653    0.426  3.542570
# 2      11.11     7.30   0.657   1.522     8.502   0.862    0.743  0.905500
# 3       9.45     7.89   0.835   1.198     8.925   0.415    0.172  0.893934
# 4      11.70     7.60   0.650   1.539     9.147   1.205    1.453  0.888476
# ..       ...      ...     ...     ...       ...     ...      ...       ...
# 247    10.53     8.38   0.796   1.257     8.989   0.499    0.249  5.415724
# 248    11.99     9.06   0.756   1.323    10.021   0.503    0.253  1.240819
# 249    13.46     9.65   0.717   1.395    10.496   0.649    0.421  3.903687
# 250     9.65     7.99   0.828   1.208     8.826   0.461    0.213  0.755152
# 251    10.04     6.91   0.688   1.453     8.154   0.680    0.463  0.912104
#
#      ecg_median     ecg_sd  fear  angry  happy  sad  class
# ...

# %%
df.head()
# Out:
#    gsr_max  gsr_min  min_ra  max_ra  gsr_mean  gsr_sd  gsr_var   ecg_avg  \
# 0     9.65     7.50   0.777   1.287     8.396   0.569    0.323  0.930028
# 1    10.04     6.91   0.688   1.453     7.763   0.653    0.426  3.542570
# 2    11.11     7.30   0.657   1.522     8.502   0.862    0.743  0.905500
# 3     9.45     7.89   0.835   1.198     8.925   0.415    0.172  0.893934
# 4    11.70     7.60   0.650   1.539     9.147   1.205    1.453  0.888476
#
#    ecg_median    ecg_sd  fear  angry  happy  sad  class
# 0    0.823296  0.479210     3      2      1    2      3
# 1    0.950501  8.880391     1      1      1    5      1
# 2    0.823431  0.307660     1      1      4    1      0
# 3    0.808990  0.460318     2      2      1    4      1
# 4    0.794695  0.325275     2      5      1    2      2

# %%
df.columns
# Out:
# Index(['gsr_max', 'gsr_min', 'min_ra', 'max_ra', 'gsr_mean', 'gsr_sd',
#        'gsr_var', 'ecg_avg', 'ecg_median', 'ecg_sd', 'fear', 'angry', 'happy',
#        'sad', 'class'],
#       dtype='object')

# %%
df.describe()
# Out:
#           gsr_max     gsr_min      min_ra      max_ra    gsr_mean      gsr_sd  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean    11.080635    7.291587    0.674492    1.692960    8.742429    0.860992
# std      3.319695    2.581644    0.170811    0.914607    2.444783    0.656332
# min      3.290000    2.510000    0.165000    1.043000    2.798000    0.124000
# 25%      9.350000    5.540000    0.637000    1.279000    7.283000    0.436000
# 50%     10.965000    7.890000    0.717500    1.394000    8.983500    0.599500
# 75%     13.660000    8.960000    0.782000    1.571000   10.017000    0.982000
# max     20.690000   12.480000    0.959000    6.064000   14.863000    2.824000
#
#           gsr_var     ecg_avg  ecg_median      ecg_sd        fear       angry  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.170794    1.164557    0.882274    1.091522    2.111111    2.174603
# ...

# %%
df.isnull().sum()
# Out:
# gsr_max       0
# gsr_min       0
# min_ra        0
# max_ra        0
# gsr_mean      0
# gsr_sd        0
# gsr_var       0
# ecg_avg       0
# ecg_median    0
# ecg_sd        0
# fear          0
# angry         0
# happy         0
# sad           0
# class         0
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gsr_max     252 non-null    float64
#  1   gsr_min     252 non-null    float64
#  2   min_ra      252 non-null    float64
#  3   max_ra      252 non-null    float64
#  4   gsr_mean    252 non-null    float64
#  5   gsr_sd      252 non-null    float64
#  6   gsr_var     252 non-null    float64
#  7   ecg_avg     252 non-null    float64
#  8   ecg_median  252 non-null    float64
#  9   ecg_sd      252 non-null    float64
#  10  fear        252 non-null    int64
#  11  angry       252 non-null    int64
#  12  happy       252 non-null    int64
#  13  sad         252 non-null    int64
#  14  class       252 non-null    int64
# dtypes: float64(10), int64(5)
# memory usage: 29.7 KB
# None

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot = True, cmap = 'terrain')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)

# %%
df.hist(figsize=(12,12), layout=(5,3));

# %%
# Box and whiskers plot
df.plot(kind = 'box' , subplots = True, layout = (5,3), figsize = (12,12))
plt.show()

# %%
sns.catplot(data=df, x = 'fear' , y = 'gsr_max', hue = 'class', palette = 'husl')

# %%
sns.barplot(data=df, x = 'fear' , y = 'min_ra', hue = 'class', palette = 'spring')
# Out:
# <AxesSubplot:xlabel='fear', ylabel='min_ra'>

# %%
df['fear'].value_counts()
# Out:
# 1    140
# 5     30
# 2     30
# 4     26
# 3     26
# Name: fear, dtype: int64

# %%
df['class'].value_counts()
# Out:
# 1    84
# 2    70
# 0    56
# 3    42
# Name: class, dtype: int64

# %%
sns.countplot(data=df, x = 'fear' , hue = 'class', palette = 'husl')
# Out:
# <AxesSubplot:xlabel='fear', ylabel='count'>

# %%
sns.countplot(x='class', palette = 'BuGn', data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x = 'fear', hue = 'class', data=df)
# Out:
# <AxesSubplot:xlabel='fear', ylabel='count'>

# %%
df['gsr_mean'].value_counts()
# Out:
# 4.126     4
# 9.690     4
# 9.437     4
# 9.042     4
# 7.763     2
#          ..
# 10.452    2
# 9.146     2
# 9.900     2
# 9.707     2
# 10.625    2
# Name: gsr_mean, Length: 122, dtype: int64

# %%
sns.countplot(x='angry',data=df,hue='class',palette='BuPu')
# Out:
# <AxesSubplot:xlabel='angry', ylabel='count'>

# %%
df['angry'].value_counts()
# Out:
# 1    144
# 5     44
# 2     28
# 4     20
# 3     16
# Name: angry, dtype: int64

# %%
sns.countplot(x='angry', hue = 'class', data=df, palette='rocket')
# Out:
# <AxesSubplot:xlabel='angry', ylabel='count'>

# %%
sns.countplot(x='fear', hue = 'angry', data=df, palette = 'BrBG')
# Out:
# <AxesSubplot:xlabel='fear', ylabel='count'>

# %%
sns.boxplot(x = 'fear', y='gsr_mean', hue = 'class', palette = 'seismic', data=df)
# Out:
# <AxesSubplot:xlabel='fear', ylabel='gsr_mean'>

# %%
sns.barplot(x='fear', y='happy', hue = 'class', data = df, palette='cividis')
# Out:
# <AxesSubplot:xlabel='fear', ylabel='happy'>

# %%
sns.barplot(x='fear', y='sad', hue = 'class', data = df, palette='nipy_spectral')
# Out:
# <AxesSubplot:xlabel='fear', ylabel='sad'>

# %%
sns.barplot(x='class', y='happy', hue = 'fear', data = df, palette='mako')
# Out:
# <AxesSubplot:xlabel='class', ylabel='happy'>

# %%
sns.barplot(x='fear', y='gsr_min', hue = 'class', data = df, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='fear', ylabel='gsr_min'>

# %%
sns.barplot(x='sad', y='gsr_min', hue = 'class', data = df, palette='plasma')
# Out:
# <AxesSubplot:xlabel='sad', ylabel='gsr_min'>

# %%
sns.barplot(x='fear', y='class', hue = 'angry', data = df)
# Out:
# <AxesSubplot:xlabel='fear', ylabel='class'>

# %%
fear = pd.crosstab(df['fear'], df['class'])
print(fear)
# Out:
# class   0   1   2   3
# fear
# 1      56  44  38   2
# 2       0  10  20   0
# 3       0   8   8  10
# 4       0  14   4   8
# 5       0   8   0  22

# %%
fear.plot(kind = 'bar',stacked = True, color=['green','yellow'],grid = False)
# Out:
# <AxesSubplot:xlabel='fear'>

# %%
temp=pd.crosstab(index=df['fear'],
            columns=[df['happy']], 
            margins=True)
temp
# Out:
# happy    1   2   3   4   5  All
# fear
# 1       76   8   8  18  30  140
# 2       30   0   0   0   0   30
# 3       24   0   2   0   0   26
# 4       24   0   2   0   0   26
# 5       28   2   0   0   0   30
# All    182  10  12  18  30  252

# %%
temp.plot(kind="bar",stacked=True)
plt.show()

# %%
temp=pd.crosstab(index=df['class'],
            columns=[df['happy']], 
            margins=True)
temp
# Out:
# happy    1   2   3   4   5  All
# class
# 0        4   0   4  18  30   56
# 1       70  10   4   0   0   84
# 2       68   0   2   0   0   70
# 3       40   0   2   0   0   42
# All    182  10  12  18  30  252

# %%
temp.plot(kind='bar', stacked=True)
plt.show()

# %%
angry = pd.crosstab(df['angry'], df['class'])
angry
# Out:
# class   0   1   2   3
# angry
# 1      52  58   0  34
# 2       4  12   4   8
# 3       0   6  10   0
# 4       0   8  12   0
# 5       0   0  44   0

# %%
angry.plot(kind='bar', stacked=True, color=['purple','blue'], grid=False)
# Out:
# <AxesSubplot:xlabel='angry'>

# %% [markdown]
# # Scaling the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()  
columns_to_scale = ['gsr_max','gsr_min','min_ra','max_ra','gsr_mean','gsr_sd','gsr_var','ecg_avg','ecg_median','ecg_sd','fear','angry','happy','sad']
df[columns_to_scale] = StandardScaler.fit_transform(df[columns_to_scale])

# %%
df.head()
# Out:
#     gsr_max   gsr_min    min_ra    max_ra  gsr_mean    gsr_sd   gsr_var  \
# 0 -0.431811  0.080889  0.601320 -0.444746 -0.141983 -0.445770 -0.451720
# 1 -0.314097 -0.148102  0.079239 -0.262886 -0.401417 -0.317531 -0.396840
# 2  0.008863  0.003265 -0.102610 -0.187294 -0.098539  0.001539 -0.227936
# 3 -0.492178  0.232257  0.941553 -0.542249  0.074827 -0.680874 -0.532176
# 4  0.186944  0.119701 -0.143672 -0.168670  0.165813  0.525180  0.150365
#
#     ecg_avg  ecg_median    ecg_sd      fear     angry     happy       sad  \
# 0 -0.289249   -0.145853 -0.276225  0.608984 -0.110577 -0.570053 -0.681536
# 1  2.932848    0.168726  3.513707 -0.761229 -0.743878 -0.570053  1.270135
# 2 -0.319500   -0.145521 -0.353615 -0.761229 -0.743878  1.501872 -1.332093
# 3 -0.333764   -0.181233 -0.284748 -0.076123 -0.110577 -0.570053  0.619578
# 4 -0.340496   -0.216583 -0.345669 -0.076123  1.789329 -0.570053 -0.681536
#
#    class
# 0      3
# 1      1
# 2      0
# 3      1
# 4      2

# %%
X= df.drop(['class'], axis=1)
y= df['class']

# %%
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=40)

# %% [markdown]
# # Check the sample Size

# %%
print('X_train-', X_train.size)
print('X_test-',X_test.size)
print('y_train-', y_train.size)
print('y_test-', y_test.size)
# Out:
# X_train- 2464
# X_test- 1064
# y_train- 176
# y_test- 76

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

model1=lr.fit(X_train,y_train)
prediction1=model1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,prediction1)
cm
# Out:
# array([[17,  0,  0,  1],
#        [ 1, 21,  2,  1],
#        [ 0,  2, 16,  0],
#        [ 0,  3,  0, 12]], dtype=int64)

# %%
sns.heatmap(cm, annot=True,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy:',(TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing Accuracy: 0.9743589743589743

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction1)
# Out:
# 0.868421052631579

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        18
#            1       0.81      0.84      0.82        25
#            2       0.89      0.89      0.89        18
#            3       0.86      0.80      0.83        15
#
#     accuracy                           0.87        76
#    macro avg       0.87      0.87      0.87        76
# weighted avg       0.87      0.87      0.87        76

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)

# %%
cm2
# Out:
# array([[18,  0,  0,  0],
#        [ 0, 25,  0,  0],
#        [ 0,  0, 18,  0],
#        [ 0,  4,  0, 11]], dtype=int64)

# %%
accuracy_score(y_test,prediction2)
# Out:
# 0.9473684210526315

# %%
print(classification_report(y_test, prediction2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.86      1.00      0.93        25
#            2       1.00      1.00      1.00        18
#            3       1.00      0.73      0.85        15
#
#     accuracy                           0.95        76
#    macro avg       0.97      0.93      0.94        76
# weighted avg       0.95      0.95      0.95        76

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
model3 = rfc.fit(X_train, y_train)
prediction3 = model3.predict(X_test)
confusion_matrix(y_test, prediction3)
# Out:
# array([[18,  0,  0,  0],
#        [ 0, 25,  0,  0],
#        [ 0,  0, 18,  0],
#        [ 0,  4,  0, 11]], dtype=int64)

# %%
accuracy_score(y_test, prediction3)
# Out:
# 0.9473684210526315

# %%
print(classification_report(y_test, prediction3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.86      1.00      0.93        25
#            2       1.00      1.00      1.00        18
#            3       1.00      0.73      0.85        15
#
#     accuracy                           0.95        76
#    macro avg       0.97      0.93      0.94        76
# weighted avg       0.95      0.95      0.95        76

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
from sklearn.svm import SVC

svm=SVC()
model4=svm.fit(X_train,y_train)
prediction4=model4.predict(X_test)
cm4= confusion_matrix(y_test,prediction4)

# %%
cm4
# Out:
# array([[16,  1,  1,  0],
#        [ 1, 21,  2,  1],
#        [ 0,  0, 18,  0],
#        [ 0,  8,  0,  7]], dtype=int64)

# %%
accuracy_score(y_test, prediction4)
# Out:
# 0.8157894736842105

# %%
from sklearn.naive_bayes import GaussianNB

NB = GaussianNB()
model5 = NB.fit(X_train, y_train)
prediction5 = model5.predict(X_test)
cm5= confusion_matrix(y_test, prediction5)

# %%
cm5
# Out:
# array([[17,  0,  1,  0],
#        [ 2, 13,  3,  7],
#        [ 1,  0, 17,  0],
#        [ 1,  6,  1,  7]], dtype=int64)

# %%
accuracy_score(y_test, prediction5)
# Out:
# 0.7105263157894737

# %%
print('cm4', cm4)
print('-----------')
print('cm5',cm5)
# Out:
# cm4 [[16  1  1  0]
#  [ 1 21  2  1]
#  [ 0  0 18  0]
#  [ 0  8  0  7]]
# -----------
# cm5 [[17  0  1  0]
#  [ 2 13  3  7]
#  [ 1  0 17  0]
#  [ 1  6  1  7]]

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier()
model6 = KNN.fit(X_train, y_train)
prediction6 = model6.predict(X_test)
cm6= confusion_matrix(y_test, prediction5)
cm6
# Out:
# array([[17,  0,  1,  0],
#        [ 2, 13,  3,  7],
#        [ 1,  0, 17,  0],
#        [ 1,  6,  1,  7]], dtype=int64)

# %%
print('KNN :', accuracy_score(y_test, prediction6))
print('lr :', accuracy_score(y_test, prediction1))
print('dtc :', accuracy_score(y_test, prediction2))
print('rfc :', accuracy_score(y_test, prediction3))
print('NB: ', accuracy_score(y_test, prediction4))
print('SVC :', accuracy_score(y_test, prediction5))
# Out:
# KNN : 0.7368421052631579
# lr : 0.868421052631579
# dtc : 0.9473684210526315
# rfc : 0.9473684210526315
# NB:  0.8157894736842105
# SVC : 0.7105263157894737

# %% [markdown]
# # Best accuracy is given by RandomForestClassifier & DecisionTreeClassifier : 94%

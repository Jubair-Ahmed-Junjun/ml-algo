# %%
# import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('marital status.csv')

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     NaN
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df.isnull().sum()
# Out:
# age       0
# status    1
# dtype: int64

# %%
handle = df['status'].median()

# %%
handle
# Out:
# 0.0

# %%
df.status = df['status'].fillna(handle)

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     0.0
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df['status'].value_counts()
# Out:
# 0.0    11
# 1.0     9
# Name: status, dtype: int64

# %%
x = df[['age']]

# %%
x
# Out:
#     age
# 0    21
# 1    33
# 2    24
# 3    28
# 4    17
# 5    33
# 6    23
# 7    30
# 8    29
# 9    22
# 10   26
# 11   20
# 12   22
# 13   24
# 14   34
# 15   29
# 16   16
# 17   18
# 18   26
# 19   25

# %%
y = df['status']

# %%
y
# Out:
# 0     0.0
# 1     1.0
# 2     0.0
# 3     1.0
# 4     0.0
# 5     1.0
# 6     0.0
# 7     0.0
# 8     1.0
# 9     0.0
# 10    1.0
# 11    0.0
# 12    0.0
# 13    0.0
# 14    1.0
# 15    1.0
# 16    0.0
# 17    0.0
# 18    1.0
# 19    1.0
# Name: status, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = .30,random_state = 1)

# %%
xtest
# Out:
#     age
# 3    28
# 16   16
# 6    23
# 10   26
# 2    24
# 14   34

# %%
ytest
# Out:
# 3     1.0
# 16    0.0
# 6     0.0
# 10    1.0
# 2     0.0
# 14    1.0
# Name: status, dtype: float64

# %% [markdown]
# # Logistic Linear Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.predict(xtest)
# Out:
# array([1., 0., 0., 0., 0., 1.])

# %%
model.score(xtest,ytest)
# Out:
# 0.8333333333333334

# %% [markdown]
# # Sigmoid Function

# %%
model.predict_proba(xtest)
# Out:
# array([[0.28697051, 0.71302949],
#        [0.9902967 , 0.0097033 ],
#        [0.80161052, 0.19838948],
#        [0.50311753, 0.49688247],
#        [0.71810555, 0.28189445],
#        [0.02465085, 0.97534915]])

# %%
# This sigmoid function outputs means that the first colomn consist NO ,and second colomn consist YES 
# Yes-> Array value equal to .5 or greater than .5 (positive sign of model)
# No -> Array value equal to .5 or greater than .5 (negative sign of model)

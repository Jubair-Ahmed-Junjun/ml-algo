# %% [markdown]
# # Pima indians diabetes dataset analysis using SVM Classification Technique

# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_csv('pima-indians-diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose\n  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6        148             72             35        0  33.6
# 1              1         85             66             29        0  26.6
# 2              8        183             64              0        0  23.3
# 3              1         89             66             23       94  28.1
# 4              0        137             40             35      168  43.1
# ..           ...        ...            ...            ...      ...   ...
# 763           10        101             76             48      180  32.9
# 764            2        122             70             27        0  36.8
# 765            5        121             72             23      112  26.2
# 766            1        126             60              0        0  30.1
# 767            1         93             70             31        0  30.4
#
#      DiabetesPedigree\n  Age  Class
# 0                 0.627   50      1
# ...

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose\n  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6        148             72             35        0  33.6
# 1             1         85             66             29        0  26.6
# 2             8        183             64              0        0  23.3
# 3             1         89             66             23       94  28.1
# 4             0        137             40             35      168  43.1
# 5             5        116             74              0        0  25.6
# 6             3         78             50             32       88  31.0
# 7            10        115              0              0        0  35.3
# 8             2        197             70             45      543  30.5
# 9             8        125             96              0        0   0.0
# 10            4        110             92              0        0  37.6
# 11           10        168             74              0        0  38.0
# ...

# %%
#Check the weather any null value present here or not  
df.isnull().sum()
# Out:
# Pregnancies           0
# Glucose\n             0
# BloodPressure         0
# SkinThickness         0
# Insulin               0
# BMI                   0
# DiabetesPedigree\n    0
# Age                   0
# Class                 0
# dtype: int64

# %%
#Drop the Label value from this data_set
x = df.drop(['Class'],axis =1 )

# %%
x
# Out:
#      Pregnancies  Glucose\n  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6        148             72             35        0  33.6
# 1              1         85             66             29        0  26.6
# 2              8        183             64              0        0  23.3
# 3              1         89             66             23       94  28.1
# 4              0        137             40             35      168  43.1
# ..           ...        ...            ...            ...      ...   ...
# 763           10        101             76             48      180  32.9
# 764            2        122             70             27        0  36.8
# 765            5        121             72             23      112  26.2
# 766            1        126             60              0        0  30.1
# 767            1         93             70             31        0  30.4
#
#      DiabetesPedigree\n  Age
# 0                 0.627   50
# 1                 0.351   31
# ...

# %%
# Separated Label Value 
y = df['Class']

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Class, Length: 768, dtype: int64

# %% [markdown]
# # Train Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = .20,random_state = 1)

# %%
xtrain
# Out:
#      Pregnancies  Glucose\n  BloodPressure  SkinThickness  Insulin   BMI  \
# 663            9        145             80             46      130  37.9
# 712           10        129             62             36        0  41.2
# 161            7        102             74             40      105  37.2
# 509            8        120             78              0        0  25.0
# 305            2        120             76             37      105  39.7
# ..           ...        ...            ...            ...      ...   ...
# 645            2        157             74             35      440  39.4
# 715            7        187             50             33      392  33.9
# 72            13        126             90              0        0  43.4
# 235            4        171             72              0        0  43.6
# 37             9        102             76             37        0  32.9
#
#      DiabetesPedigree\n  Age
# 663               0.637   40
# 712               0.441   38
# ...

# %%
model = SVC()

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC()

# %% [markdown]
# # Test Score

# %%
model.score(xtest,ytest)
# Out:
# 0.7857142857142857

# %%
# This model gave 78% acurate answer by using SVM CLassification Technique.

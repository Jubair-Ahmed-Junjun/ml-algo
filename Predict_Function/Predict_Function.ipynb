# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('cardio_train.csv',sep = ';')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# ...

# %%
y = df.iloc[:,12]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le_x = LabelEncoder()

# %%
x = x.apply(LabelEncoder().fit_transform)

# %%
x
# Out:
#           id   age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  3464       1      75      75     37     43            0     0
# 1          1  5030       0      63     173     67     53            2     0
# 2          2  3833       0      72      85     57     33            2     0
# 3          3  2811       1      76     157     77     63            0     0
# 4          4  2662       0      63      52     27     23            0     0
# ...      ...   ...     ...     ...     ...    ...    ...          ...   ...
# 69995  69995  4215       1      75     139     47     43            0     0
# 69996  69996  7130       0      65     235     67     53            1     1
# 69997  69997  4042       1      90     206    107     53            2     0
# 69998  69998  6960       0      70     122     62     43            0     1
# 69999  69999  5342       0      77     122     47     43            1     0
#
#        smoke  alco  active
# 0          0     0       1
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
import numpy as np

# %%
dtf = DecisionTreeClassifier()

# %%
dtf.fit(x.iloc[:,0:12],y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Test a Data using predict() Function
# # Taking a patient symptoms value for testing data from dataset

# %%
xinput = np.array([0,3464,1,75,75,37,43,0,0,0,0,1])

# %%
xinput
# Out:
# array([   0, 3464,    1,   75,   75,   37,   43,    0,    0,    0,    0,
#           1])

# %%
y_predict = dtf.predict([xinput])

# %%
y_predict
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # here predict value for this particular patient is 0(zero).That's means his/her cardio problem absent.

# %%
#import library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv("car data.csv")

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         NaN    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
df.experience
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     NaN
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
df.experience.mean()
# Out:
# 6.6

# %%
exp_fit = df.experience.median()

# %%
exp_fit
# Out:
# 5.0

# %%
df.experience = df.experience.fillna(exp_fit)

# %%
df.experience
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     5.0
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         5.0    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['speed','car_age','experience']],df.risk)
# Out:
# LinearRegression()

# %%
reg.predict([[180,10,5]])
# Out:
# array([77.98331208])

# %%
reg.coef_
# Out:
# array([ 0.33059217,  1.61053246, -6.20772074])

# %%
reg.intercept_
# Out:
# 33.410000910435905

# %%
# y = mx + c
# Y = M1*X1 + M2*X2 + M3*X3 + ..... + Mn*Xn + C
# risk = M1*speed + M2*car_age + M3*experience + C
# M = Coefficience Y= Dependend variable speed,car_age,experience = Independend Variable C = Intercept
car_risk = 0.33059217*180+1.61053246*10+(-6.20772074)*5 + 33.410000910435905

# %%
risk
# Out:
# 77.9833124104359

# %%
# we can show the value of risk & the value of predict both are same
